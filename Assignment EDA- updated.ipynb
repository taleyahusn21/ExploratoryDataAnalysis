# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("adult.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %% [markdown]
# # Univariate Analysis
# *Age*

# %%
df['age'].describe()
# Out:
# count    48842.000000
# mean        38.643585
# std         13.710510
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df['age'].plot(kind='box')
plt.xlabel('Age')
plt.ylabel('Values')
plt.title('Box Plot of Age Distribution')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age Distribution')

# %% [markdown]
# *We can clearly see there are outliers in the age column*

# %%
percentile25= df['age'].quantile(0.25)
percentile75= df['age'].quantile(0.75)

# %%
IQR = percentile75- percentile25

# %%
IQR
# Out:
# 20.0

# %%
upperlimit = percentile75 + 1.5 * IQR
lowerlimit = percentile75 - 1.5 * IQR

# %%
upperlimit
# Out:
# 78.0

# %%
lowerlimit
# Out:
# 18.0

# %% [markdown]
# ##### Below 18 and above 78 are all outliers

# %%
#checking number of rows above upper limit
df[df['age'] > upperlimit]
# Out:
#        age         workclass  fnlwgt   education  educational-num  \
# 193     79                 ?   48574     7th-8th                4
# 234     80  Self-emp-not-inc  201092     HS-grad                9
# 899     90           Private  149069  Assoc-acdm               12
# 926     79                 ?   27457     Masters               14
# 951     80           Private  138050     HS-grad                9
# ...    ...               ...     ...         ...              ...
# 48558   90           Private  313749     HS-grad                9
# 48648   90         Local-gov  214594     7th-8th                4
# 48740   85           Private   98611   Bachelors               13
# 48775   82                 ?  403910     HS-grad                9
# 48806   81                 ?  120478   Assoc-voc               11
#
#               marital-status         occupation   relationship   race  gender  \
# 193                  Widowed                  ?  Not-in-family  White    Male
# ...

# %%
df[df['age'] < lowerlimit]
# Out:
#        age workclass  fnlwgt education  educational-num marital-status  \
# 38      17   Private  269430      10th                6  Never-married
# 75      17         ?  165361      10th                6  Never-married
# 402     17   Private   40299      11th                7  Never-married
# 675     17   Private  190941      10th                6  Never-married
# 765     17         ?  143331      11th                7  Never-married
# ...    ...       ...     ...       ...              ...            ...
# 48053   17         ?  256173      10th                6  Never-married
# 48145   17   Private  214787      12th                8  Never-married
# 48240   17   Private   24090   HS-grad                9  Never-married
# 48563   17   Private  311907      11th                7  Never-married
# 48728   17   Private  117798      10th                6  Never-married
#
#               occupation   relationship   race  gender  capital-gain  \
# ...

# %%
#handling outliers using capping
new_df=df.copy()
new_df['age']=np.where(new_df['age']>upperlimit, upperlimit, 
                       np.where(new_df['age']<lowerlimit,lowerlimit,new_df['age']))

# %%
#comparing
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.boxplot(df['age'])

plt.subplot(2,2,2)
sns.boxplot(new_df['age'])
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# Now we can clearly see no outliers are present

# %%
new_df['age'].plot(kind='hist')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age Distribution')
# Out:
# Text(0.5, 1.0, 'Histogram of Age Distribution')

# %% [markdown]
# Maximum number of people are between age 35-45

# %%
new_df['age'].plot(kind='kde')
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Kernel Density Estimate of Age Distribution')
# Out:
# Text(0.5, 1.0, 'Kernel Density Estimate of Age Distribution')

# %%
new_df['age'].skew()
# Out:
# 0.5217510648713486

# %% [markdown]
# Age is normally distributed

# %%
df['age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# *CAPITAL LOSS*

# %%
df['capital-loss'].describe()
# Out:
# count    48842.000000
# mean        87.502314
# std        403.004552
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital-loss, dtype: float64

# %%
df['capital-loss'].plot(kind='hist')
plt.xlabel('Capital Loss')
plt.ylabel('Frequency')
plt.title('Histogram of Capital Loss Distribution')
# Out:
# Text(0.5, 1.0, 'Histogram of Capital Loss Distribution')

# %% [markdown]
# *Observations*
# <br>Maximum number of people has not faced any capital-loss

# %%
df['capital-loss'].plot(kind='kde')
plt.xlabel('Capital Loss')
plt.ylabel('Density')
plt.title('Kernel Density Estimate of Capital Loss Distribution')
# Out:
# Text(0.5, 1.0, 'Kernel Density Estimate of Capital Loss Distribution')

# %%
df['capital-loss'].skew()
# Out:
# 4.569808857738484

# %% [markdown]
# *Observation*
# <br> The data is positively skewed

# %%
df['capital-loss'].plot(kind='box')
plt.ylabel('Capital Loss')
plt.title('Box Plot of Capital Loss Distribution')
# Out:
# Text(0.5, 1.0, 'Box Plot of Capital Loss Distribution')

# %% [markdown]
# *Observation*
# <br> Maximum people has not faced any capital loss

# %%
df.loc[df['capital-loss'] > 0,['capital-loss']].describe()
# Out:
#        capital-loss
# count   2282.000000
# mean    1872.825592
# std      364.048529
# min      155.000000
# 25%     1672.000000
# 50%     1887.000000
# 75%     1977.000000
# max     4356.000000

# %%
df['capital-loss'].isnull().sum()
# Out:
# 0

# %% [markdown]
# *CAPITAL GAIN*

# %%
df['capital-gain'].describe()
# Out:
# count    48842.000000
# mean      1079.067626
# std       7452.019058
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital-gain, dtype: float64

# %%
df.loc[df['capital-gain'] > 0,['capital-gain']].describe()
# Out:
#        capital-gain
# count   4035.000000
# mean   13061.665675
# std    22711.237412
# min      114.000000
# 25%     3411.000000
# 50%     7298.000000
# 75%    13550.000000
# max    99999.000000

# %%
df['capital-gain'].plot(kind='kde')
plt.xlabel('Capital Gain')
plt.ylabel('Density')
plt.title('Kernel Density Estimate of Capital Gain Distribution')
# Out:
# Text(0.5, 1.0, 'Kernel Density Estimate of Capital Gain Distribution')

# %%
df['capital-gain'].skew()
# Out:
# 11.894658996587946

# %% [markdown]
# *Observation*
# <br>The data is positively skewed

# %%
df['capital-gain'].plot(kind='box')
plt.ylabel('Capital Gain')
plt.title('Box Plot of Capital Gain Distribution')
# Out:
# Text(0.5, 1.0, 'Box Plot of Capital Gain Distribution')

# %% [markdown]
# *Observation*
# <br>Maximum people has 0 capital-gain

# %%
df['capital-gain'].isnull().sum()
# Out:
# 0

# %% [markdown]
# *EDUCATIONAL-NUM*

# %%
df['educational-num'].describe()
# Out:
# count    48842.000000
# mean        10.078089
# std          2.570973
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: educational-num, dtype: float64

# %%
df['educational-num'].plot(kind='hist')
plt.xlabel('Educational Number')
plt.ylabel('Frequency')
plt.title('Histogram of Educational Number Distribution')
# Out:
# Text(0.5, 1.0, 'Histogram of Educational Number Distribution')

# %% [markdown]
# *Observation*
# <br> Maximum number of people has studied for 9-10 years

# %%
df['educational-num'].plot(kind='box')
plt.ylabel('Educational Number')
plt.title('Box Plot of Educational year')
# Out:
# Text(0.5, 1.0, 'Box Plot of Educational year')

# %% [markdown]
# *Observations-*
# <br>Minimum yrs of education is 5
# <br>Maximum yrs of education is 16
# <br>10 is the median years of education

# %%
df['educational-num'].isnull().sum()
# Out:
# 0

# %%
df['hours-per-week'].describe()
# Out:
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
df['hours-per-week'].plot(kind='hist')
plt.xlabel('Hours per Week')
plt.ylabel('Frequency')
plt.title(' Hours per Week Distribution')
# Out:
# Text(0.5, 1.0, ' Hours per Week Distribution')

# %% [markdown]
# Observation-
# <br>> Majority of people has worked for 30-40 hours

# %% [markdown]
# *INCOME*

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
df['income'].value_counts().plot(kind='bar')
plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Income Distribution')
# Out:
# Text(0.5, 1.0, 'Income Distribution')

# %%
df['income'].value_counts().plot(kind='pie',autopct= '%0.1f%%')
plt.title('Income Distribution')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df['income'].isnull().sum()
# Out:
# 0

# %% [markdown]
# *relationship*

# %%
df['relationship'].value_counts()
# Out:
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64

# %%
df['relationship'].value_counts().plot(kind='bar')
plt.xlabel('Relationship')
plt.ylabel('Count')
plt.title('Relationship Distribution')
# Out:
# Text(0.5, 1.0, 'Relationship Distribution')

# %%
df['relationship'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.title('Relationship Distribution')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df['relationship'].isnull().sum()
# Out:
# 0

# %% [markdown]
# *Native Country*

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %% [markdown]
# Observation:
# There is an unknown country reresented as '?' in native-country column

# %%
import numpy as np
df['native-country'].replace('?', np.NaN, inplace = True)

# %%
df['native-country'].fillna(df['native-country'].mode()[0], inplace=True)

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 44689
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %% [markdown]
# Filled the '?' values ith the most frequent country, here it is United States

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             36705
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %% [markdown]
# *Observation*
# <br> There is unknown category of workclass marked as '?'

# %%
df['workclass'].replace('?', np.NaN, inplace = True)

# %%
df['workclass'].fillna(df['workclass'].mode()[0], inplace=True)

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             36705
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %% [markdown]
# The '?' has been filled by most frequent value

# %%
workclass_mapping = {
    'Self-emp-not-inc': 'Self-employed',
    'Self-emp-inc': 'Self-employed',
    'Local-gov': 'Government',
    'State-gov': 'Government',
    'Federal-gov': 'Government'
}

# %%
df['workclass'].replace(workclass_mapping, inplace=True)

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private          36705
# Government        6549
# Self-employed     5557
# Without-pay         21
# Never-worked        10
# Name: count, dtype: int64

# %%
df['workclass'].value_counts().plot(kind='bar')
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.title('Workclass Distribution')
# Out:
# Text(0.5, 1.0, 'Workclass Distribution')

# %% [markdown]
# MARITAL STATUS

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
marital_status_mapping = {
    'Married-spouse-absent': 'Married',
    'Married-civ-spouse': 'Married',
    'Married-AF-spouse': 'Married',
    'Separated': 'Separated',
    'Divorced': 'Separated'  
}
df['marital-status'].replace(marital_status_mapping, inplace=True)

# %%
df['marital-status'].value_counts()
# Out:
# marital-status
# Married          23044
# Never-married    16117
# Separated         8163
# Widowed           1518
# Name: count, dtype: int64

# %% [markdown]
# Done this to group the data.

# %%
df['marital-status'].value_counts().plot(kind='bar')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.title('Marital Status Distribution')
# Out:
# Text(0.5, 1.0, 'Marital Status Distribution')

# %% [markdown]
# EDUCATION

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %% [markdown]
# Observation-
# <br>>9th,10th,11th,12th can be grouped under 'HighSchool' Category
# <br>>1st-8th can be grouped under elementary

# %%
education_mapping = {
    '9th': 'HighSchool',
    '10th': 'HighSchool',
    '11th': 'HighSchool',
    '12th': 'HighSchool',
    '1st-4th': 'elementary',
    '5th-6th': 'elementary',
    '7th-8th': 'elementary'
}

# %%
df['education'].replace(education_mapping, inplace= True)

# %%
df['education'].value_counts().plot(kind='bar')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Education Level Distribution')
# Out:
# Text(0.5, 1.0, 'Education Level Distribution')

# %% [markdown]
# *Observations*
# <br>>Maximum number of people are HS-grad

# %% [markdown]
# OCCUPATION

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['occupation'].replace('?', 'Unknown', inplace=True)

# %% [markdown]
# There was an unknown value in occupation column marked as '?', therefore i have replaced it with unknown

# %%
df['occupation'].value_counts().plot(kind='bar')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Occupation Distribution')
# Out:
# Text(0.5, 1.0, 'Occupation Distribution')

# %%
df['race'].value_counts()
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
df['race'].value_counts().plot(kind='bar')
plt.xlabel('Race')
plt.ylabel('Count')
plt.title('Race Distribution')
# Out:
# Text(0.5, 1.0, 'Race Distribution')

# %% [markdown]
# Observation-
# <br>>White is the dominant category in race

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
df['gender'].value_counts().plot(kind='pie',autopct='%0.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# Observation-
# <br>>Males have more job as compared to female

# %% [markdown]
# # Bivariate Analysis
# INCOME-GENDER

# %%
pd.crosstab(df['income'],df['gender'],normalize='columns')*100
# Out:
# gender     Female       Male
# income
# <=50K   89.074852  69.623277
# >50K    10.925148  30.376723

# %% [markdown]
# *Observation*
# <br>>Only 10 percent of female and 30 percent of male has income greater than 50K

# %% [markdown]
# INCOME-RACE

# %%
pd.crosstab(df['income'],df['race'],normalize='columns')*100
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander     Black      Other      White
# income
# <=50K            88.297872           73.074391  87.91889  87.684729  74.601312
# >50K             11.702128           26.925609  12.08111  12.315271  25.398688

# %% [markdown]
# Observation-
# <br>>Only Asian-Pac-Islander and White people has 25% of people having salary greater than 50K.

# %%
pd.crosstab(df['income'],df['education'],normalize='columns')*100
# Out:
# education  Assoc-acdm  Assoc-voc  Bachelors  Doctorate    HS-grad  HighSchool  \
# income
# <=50K       74.203623  74.672489  58.716511  27.441077  84.142169   94.191591
# >50K        25.796377  25.327511  41.283489  72.558923  15.857831    5.808409
#
# education    Masters  Preschool  Prof-school  Some-college  elementary
# income
# <=50K      45.088446  98.795181    26.019185     81.035117   94.330801
# >50K       54.911554   1.204819    73.980815     18.964883    5.669199

# %% [markdown]
# *Observations*
# <br>>Person having education level is doctorate, Masters or prof-school has salary greater than 50K. However they are less in the data.
# <br>>HS-grad(Highest number of people in the data) has only 15% people having salary greater than 50K

# %%
pd.crosstab(df['income'],df['occupation'],normalize='columns')*100
# Out:
# occupation  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# income
# <=50K            86.3126     66.666667     77.372382        52.218206
# >50K             13.6874     33.333333     22.627618        47.781794
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# income
# <=50K             88.389262          93.339768          87.690271
# >50K              11.610738           6.660232          12.309729
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# income
# <=50K           95.856185        98.760331       54.893065        68.667345
# >50K             4.143815         1.239669       45.106935        31.332655
#
# occupation      Sales  Tech-support  Transport-moving    Unknown
# income
# <=50K       73.201308     70.954357         79.575372  90.566038
# >50K        26.798692     29.045643         20.424628   9.433962

# %% [markdown]
# Observation-
# <br>>Executive managerial post have the highest number of people with >50K Salary

# %%
pd.crosstab(df['income'],df['marital-status'],normalize='columns')*100
# Out:
# marital-status    Married  Never-married  Separated    Widowed
# income
# <=50K           56.361743      95.452007  90.567193  91.567852
# >50K            43.638257       4.547993   9.432807   8.432148

# %% [markdown]
# Observation-
# <br>>Married category has more people having salary >50K

# %%
df[df['income']=='<=50K']['age'].plot(kind='kde',label='Income less than 50K')
df[df['income']=='>50K']['age'].plot(kind='kde',label='Income greater than 50K')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Density')
plt.title(' Age by Income Group')
plt.legend()
plt.show()

# %% [markdown]
# *Observations*-
# <br>>between age 10-30 income is less than 50K
# <br>>between age 30-70 income is more than 50K

# %%
df[df['income']=='<=50K']['hours-per-week'].plot(kind='kde',label='Income less than 50K')
df[df['income']=='>50K']['hours-per-week'].plot(kind='kde',label='Income greater than 50K')
plt.xlabel('Hours per Week')
plt.ylabel('Density')
plt.title('Hours per Week by Income Group')
plt.legend()
plt.show()

# %% [markdown]
# *Observations*
# <br>>Person who works less than 40 hours has income less than 50 K
# <br>>Person who works more than 40 hours has income more than 50 K

# %%
df[df['income']=='<=50K']['educational-num'].plot(kind='kde',label='Income less than 50K')
df[df['income']=='>50K']['educational-num'].plot(kind='kde',label='Income greater than 50K')
plt.xlabel('Educational Number')
plt.ylabel('Density')
plt.title('Educational Number by Income Group')
plt.legend()
plt.show()

# %% [markdown]
# *Observation*:
# <br>>Person who studied more than 12 years has salary greater thab 50K

# %%
numeric_df = df[['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']]
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Correlation Matrix of Numerical Parameters')
plt.show()

# %% [markdown]
# Observation-
# <br>The variables are weakly correlated

# %% [markdown]
# # Conclusion
# FOLLOWING ARE THE POSSIBLE CAUSES WHICH AFFECT INCOME-
# <br>>Gender, as we have seen in the bivariate analysis the percent of female having salary greater than 50k is 10%.
# <br>>Race, as we know there are white people in more number in the dataset and during Bivariate analysis we have seen more than 25% of white people has salary greater than 50K.
# <br>>Person having education level doctorate, Masters or prof-school has salary greater than 50K.
# <br>>Prof-Speciality and executive managers has more number of people having salary greater than 50K
# <br>>Marriage can also a possible cause as seen in bivariate analysis more than 43% married people has salary greater than 50K
# <br>>Work hour- More work hour more income, person having work hour more than 40 hours has salary grater than 50K
# <br>>Person having more educational-year has more income.
